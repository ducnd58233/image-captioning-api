# %%
import os
import csv
import time
from datetime import datetime, timezone
from io import BytesIO

import requests
from googletrans import Translator
from PIL import Image
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

# %%
import logging

class LogCustomFormatter(logging.Formatter):
    grey = "\x1b[0;37m"
    green = "\x1b[1;32m"
    bold_red = "\x1b[31;1m"
    yellow = "\x1b[1;33m"
    red = "\x1b[1;31m"
    purple = "\x1b[1;35m"
    blue = "\x1b[1;34m"
    light_blue = "\x1b[1;36m"
    reset = "\x1b[0m"
    blink_red = "\x1b[5m\x1b[1;31m"

    format = '%(asctime)s - %(name)s - %(levelname)s - %(message)s (%(filename)s:%(lineno)d)'

    FORMATS = {
        logging.DEBUG: grey + format + reset,
        logging.INFO: grey + format + reset,
        logging.WARNING: yellow + format + reset,
        logging.ERROR: red + format + reset,
        logging.CRITICAL: bold_red + format + reset
    }

    def format(self, record):
        log_fmt = self.FORMATS.get(record.levelno)
        formatter = logging.Formatter(log_fmt)
        return formatter.format(record)
    
def setup_logger(logger_name, output_dir = None):
    # Remove existing handlers if the logger already exists
    logger = logging.getLogger(logger_name)
    for handler in logger.handlers[:]:
        logger.removeHandler(handler)

    logger.setLevel(logging.DEBUG)
    
    # create console handler with a higher log level
    ch = logging.StreamHandler()
    ch.setLevel(logging.DEBUG)
    # create formatter and add it to the handlers
    formatter = LogCustomFormatter()
    ch.setFormatter(formatter)
    # add the handlers to logger
    logger.addHandler(ch)
    
    if output_dir:
        # create file handler which logs even debug messages
        fh = logging.FileHandler(os.path.join(output_dir, 'crawl_log.log'))
        fh.setLevel(logging.DEBUG)
        fh.setFormatter(formatter)
        logger.addHandler(fh)
    return logger

# %% [markdown]
# ## Crawl data

# %%
import glob

def is_today(date_str):
    today = datetime.today().strftime('%Y-%m-%d')
    return date_str == today

def get_newest_folder_name(directory, pattern='*-*-*'):
    folders = glob.glob(os.path.join(directory, pattern), recursive=True)
    today = datetime.today().strftime('%Y-%m-%d')
    
    if not folders:
        return f'{directory}/{today}'
    
    current_newest_folder = max(folders, key=os.path.getctime)
    current_newest_folder_date = current_newest_folder.split('/')[-1]
    
    return newest_folder if is_today(current_newest_folder_date) else f'{directory}/{today}'

# %%
root_dir = f'{os.getcwd()}/data'

folder_name = get_newest_folder_name(root_dir)

images_dir = os.path.join(
    folder_name,
    'images'
)

captions_path = os.path.join(
    folder_name,
    'captions.csv'
)

img_path = f'images/'

os.makedirs(root_dir, exist_ok=True)
os.makedirs(images_dir, exist_ok=True)

WEBDRIVER_DELAY_TIME_INT = 2

# %%
class CrawlData:
    def __init__(self, name, logger, page_start, page_end, lock):
        chrome_options = webdriver.ChromeOptions()

        chrome_options.add_argument('--disable-gpu')
        chrome_options.add_argument('--headless')
        chrome_options.add_argument('--no-sandbox')
        chrome_options.add_argument('--allow-running-insecure-content')
        chrome_options.add_argument('--accept-insecure-certs')
        chrome_options.add_argument('--incognito')

        chrome_options.headless = True

        self.translator = Translator()
        
        self.name = name
        self.logger = logger
        self.page_start = page_start
        self.page_end = page_end
        self.driver = webdriver.Chrome(options=chrome_options)
        self.driver.implicitly_wait(4)
        self.wait = WebDriverWait(self.driver, WEBDRIVER_DELAY_TIME_INT)
        self.page_idx = page_start
        self.lock = lock
    
    def run(self):
        categories = ['kh-vu-tru', 'anh-dep', 'moi-truong', 'moi-truong/thien-nhien', 'con-trung-vi-khuan', 'cong-nghe/phat-minh-kh']
        for self.category in categories:
            for page_idx in range(self.page_start, self.page_end):
                news_page_urls = self._get_main_page_information(self.category, page_idx)
                self.page_idx = page_idx
                for news_page_url in news_page_urls:
                    self._get_news_page_information(news_page_url)
                    time.sleep(WEBDRIVER_DELAY_TIME_INT)
                    self.driver.back()
                    time.sleep(WEBDRIVER_DELAY_TIME_INT)
    
    def _get_main_page_information(self, category, page_idx):
        main_url = f'https://kienthuckhoahoc.org/{category}/page{page_idx}'
        self.driver.get(main_url)
        news_lst_xpath = './/a[@class="title"]'
        time.sleep(WEBDRIVER_DELAY_TIME_INT)
        news_tags = self.driver.find_elements(
            By.XPATH,
            news_lst_xpath
        )

        return [news_tag.get_attribute('href') for news_tag in news_tags]

    def _get_news_page_information(self, url):
        self.driver.get(url)
        img_box_xpath = './/div[@class="img-box"]/img'
        time.sleep(WEBDRIVER_DELAY_TIME_INT)
        img_box_tags = self.driver.find_elements(
            By.XPATH,
            img_box_xpath
        )

        img_box_captions_set = set()
        if img_box_tags:
            for img_box_tag in img_box_tags:
                self._get_image_information(img_box_captions_set)
    
    def _get_image_information(self, img_box_captions_set):
        self.lock.acquire()
        try:
            img_tag = self.wait.until(
                EC.visibility_of_element_located(
                    (
                        By.TAG_NAME,
                        'img'
                    )
                )
            )

            img_caption = img_tag.get_attribute('alt')

            if img_caption not in img_box_captions_set:
                img_box_captions_set.add(img_caption)
                img_url = img_tag.get_attribute('src')

                if img_url[-3:] != 'gif' and img_caption and img_url:
                    self._save_image_information(img_url, img_caption)
                else:
                    self.logger.error(
                        f'{self.category} - Page: {self.page_idx} / {(self.page_end - 1)} - Failed to save image: Image not found')

        except Exception as e:
            self.logger.error(
                f'{self.category} - Page: {self.page_idx} / {(self.page_end - 1)} - Failed to save image: {e}')

        time.sleep(WEBDRIVER_DELAY_TIME_INT)
        self.lock.release()

    def _save_image_information(self, img_url, img_caption):
        img_url_resp = requests.get(img_url)
        translation = self.translator.translate(img_caption, dest='en')
        img_caption = translation.text

        img = Image.open(BytesIO(img_url_resp.content))

        if img.mode == 'P':
            img = img.convert('RGB')

        img_name = f'IMG_{int(datetime.now(timezone.utc).timestamp() * 1000)}.jpg'
        img_save_path = os.path.join(images_dir, img_name)
        
        if not os.path.exists(captions_path):
            with open(captions_path, 'w', encoding='utf8', newline='') as f:
                csv_writer = csv.writer(f, delimiter='|')
                csv_writer.writerow(['image', 'caption'])

        with open(captions_path, 'a+', encoding='utf8', newline='') as f:
            csv_writer = csv.writer(f, delimiter='|')
            csv_writer.writerow([img_path + img_name, img_caption])
            img.save(img_save_path)

            self.logger.info(
                f'{self.category} - Page: {self.page_idx} / {(self.page_end - 1)} - Success saved image: {img_name} - {img_caption}')

# %%
import logging

from threading import Thread, Lock

class CrawlThreadGroup:
    def __init__(self, num_thread = 1, page_size = 1):
        self.num_thread = num_thread
        self.page_size = page_size

    def run(self):
        page_start = 1
        page_end = page_start + self.page_size
        running_threads = []
        for i in range(self.num_thread):
            try:
                thread = CrawlThread(f'thread {i}', page_start, page_end)
                thread.start()
                running_threads.append(thread)
                page_start = page_end
                page_end = page_start + self.page_size
            except Exception as e:
                print(e)

        for running_thread in running_threads:
            running_thread.join()
            running_thread.stop()

class CrawlThread(Thread):
    def __init__(self, name, page_start, page_end):
        super(CrawlThread, self).__init__()
        self.logger = setup_logger(name)
        self.logger.setLevel(logging.INFO)
        self.name = name
        self.page_start = page_start
        self.page_end = page_end
        self.lock = Lock()
        self.should_run = True

    def run(self):
        self.logger.info(self.name + " is starting...")
        while self.should_run:
            process = CrawlData(self.name, self.logger, self.page_start, self.page_end, self.lock)
            process.run()
            self.logger.info(self.name + " DONE!")
            self.should_run = False
    
    def stop(self):
        self.logger.info(self.name + " is leaving...")
        self.should_run = False  # Method to stop the thread externally

    def is_running(self):
        return self.should_run

# %% [markdown]
# ## Start Crawl Data

# %%
PAGE_SIZE = 15
NUM_THREAD = 3
crawl_thread_group = CrawlThreadGroup(NUM_THREAD, PAGE_SIZE)
crawl_thread_group.run()
# Out:
# 2024-02-06 21:29:47,516 - thread 0 - INFO - thread 0 is starting... (213778126.py:40)
# 2024-02-06 21:29:47,517 - thread 1 - INFO - thread 1 is starting... (213778126.py:40)
# 2024-02-06 21:29:47,518 - thread 2 - INFO - thread 2 is starting... (213778126.py:40)
# 2024-02-06 21:29:54,405 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 1 / 15 - Success saved image: IMG_1707229794401.jpg - The giant black hole is aggressive, preventing its host galaxy from giving birth to new stars (94257464.py:118)
# 2024-02-06 21:29:54,626 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 31 / 45 - Success saved image: IMG_1707229794614.jpg - Simulation of Australia's first robotic explorer on the surface of the Moon. (94257464.py:118)
# 2024-02-06 21:30:00,153 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 16 / 30 - Success saved image: IMG_1707229800138.jpg - Scientists discovered there is atomic oxygen in the atmosphere of Venus. (94257464.py:118)
# 2024-02-06 21:30:04,063 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 1 / 15 - Success saved image: IMG_1707229804060.jpg - Diamonds are created and fall like rain on icy gas planets (94257464.py:118)
# 2024-02-06 21:30:04,559 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 31 / 45 - Success saved image: IMG_1707229804554.jpg - This exoplanet has a mass 73.2 times that of Earth. (94257464.py:118)
# 2024-02-06 21:30:10,231 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 16 / 30 - Success saved image: IMG_1707229810229.jpg - The next 18 months are the last chance to see Saturn's rings before they disappear (94257464.py:118)
# 2024-02-06 21:30:14,481 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 1 / 15 - Success saved image: IMG_1707229814466.jpg - The Dream Chaser space plane at the Neil Armstrong testing facility. (94257464.py:118)
# 2024-02-06 21:30:18,709 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 31 / 45 - Success saved image: IMG_1707229818700.jpg - The crater that Pragyan encountered on August 27 (left) and the robot's return path on the Moon. (94257464.py:118)
# 2024-02-06 21:30:20,142 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 16 / 30 - Success saved image: IMG_1707229820140.jpg - LignoSat magnolia wood satellite (94257464.py:118)
# 2024-02-06 21:30:24,412 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 1 / 15 - Success saved image: IMG_1707229824402.jpg - Simulation of exomoons orbiting planets outside the Solar System. (94257464.py:118)
# 2024-02-06 21:30:28,463 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 31 / 45 - Success saved image: IMG_1707229828460.jpg - India's first solar research mission took place on September 2 photo 0 (94257464.py:118)
# 2024-02-06 21:30:30,341 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 16 / 30 - Success saved image: IMG_1707229830321.jpg - The Euclid Telescope has just released a breathtaking panoramic photo of the Horsehead Nebula. (94257464.py:118)
# 2024-02-06 21:30:34,180 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 1 / 15 - Success saved image: IMG_1707229834172.jpg - Quasar J2054-0005 shines brightly in the early universe and is "slaughtering" a galaxy (94257464.py:118)
# 2024-02-06 21:30:38,069 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 31 / 45 - Success saved image: IMG_1707229838064.jpg - Soviet satellite Sputnik 1 (94257464.py:118)
# 2024-02-06 21:30:40,068 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 16 / 30 - Success saved image: IMG_1707229840064.jpg - Pluto's cold environment is extremely scary (94257464.py:118)
# 2024-02-06 21:30:44,944 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 1 / 15 - Success saved image: IMG_1707229844934.jpg - Simulate the phases of a total solar eclipse. (94257464.py:118)
# 2024-02-06 21:30:55,071 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 1 / 15 - Success saved image: IMG_1707229855063.jpg - Simulate the idea of ​​using an umbrella as wide as Argentina to block solar radiation. (94257464.py:118)
# 2024-02-06 21:30:56,117 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 31 / 45 - Success saved image: IMG_1707229856114.jpg - Stunning images reveal Nebula Arc like never before photo 0 (94257464.py:118)
# 2024-02-06 21:31:00,358 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 16 / 30 - Success saved image: IMG_1707229860347.jpg - The unique orbit of the 6-planet system HD 110067 (94257464.py:118)
# 2024-02-06 21:31:05,451 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 1 / 15 - Success saved image: IMG_1707229865447.jpg - Russian cosmonaut Oleg Kononenko (94257464.py:118)
# 2024-02-06 21:31:06,018 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 31 / 45 - Success saved image: IMG_1707229866012.jpg - The asteroid Psyche will be the target of this mission. (94257464.py:118)
# 2024-02-06 21:31:10,556 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 16 / 30 - Success saved image: IMG_1707229870553.jpg - The Long March 7A rocket carrying the TJS-10 satellite was launched on November 3. (94257464.py:118)
# 2024-02-06 21:31:15,431 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 1 / 15 - Success saved image: IMG_1707229875422.jpg - strong>The south polar region of the Moon typically experiences a very long period of darkness due to the tilt of the axis. However, there are three parts of this Shackleton crater rim that can receive light... (94257464.py:118)
# 2024-02-06 21:31:17,803 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 31 / 45 - Success saved image: IMG_1707229877800.jpg - India has completed its mission to land and do scientific research at the south pole of the Moon (94257464.py:118)
# 2024-02-06 21:31:20,552 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 16 / 30 - Success saved image: IMG_1707229880540.jpg - Looking at the Earth from space will realize "humanity lies to itself" photo 0 (94257464.py:118)
# 2024-02-06 21:31:25,097 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 1 / 15 - Success saved image: IMG_1707229885083.jpg - Dmitry Kryokov believes that the structure and laws of development of the universe are very similar to the human brain. (94257464.py:118)
# 2024-02-06 21:31:32,845 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 16 / 30 - Success saved image: IMG_1707229892842.jpg - Relativity and quantum mechanics are two foundations of modern physics (94257464.py:118)
# 2024-02-06 21:31:33,478 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 31 / 45 - Success saved image: IMG_1707229893474.jpg - Spaceships in orbit are flying in a region of space full of "obstacles" (94257464.py:118)
# 2024-02-06 21:31:43,196 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 31 / 45 - Success saved image: IMG_1707229903194.jpg - SpaceX brings the "most international" crew in history to the ISS station photo 0 (94257464.py:118)
# 2024-02-06 21:31:45,060 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 1 / 15 - Success saved image: IMG_1707229905042.jpg - The new giant crowded star cluster is called G333.23-0.06 (94257464.py:118)
# 2024-02-06 21:31:54,462 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 16 / 30 - Success saved image: IMG_1707229914459.jpg - Asteroid Bennu (94257464.py:118)
# 2024-02-06 21:31:54,513 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 31 / 45 - Success saved image: IMG_1707229914503.jpg - The Moon's cratered surface (94257464.py:118)
# 2024-02-06 21:31:55,561 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 1 / 15 - Success saved image: IMG_1707229915558.jpg - A fragment of asteroid 2024 BX1. (94257464.py:118)
# 2024-02-06 21:32:05,568 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 1 / 15 - Success saved image: IMG_1707229925566.jpg - Simulation of the SLIM spacecraft on the surface of the Moon. (94257464.py:118)
# 2024-02-06 21:32:05,670 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 31 / 45 - Success saved image: IMG_1707229925668.jpg - India's self-propelled robot rolls on the Moon photo 0 (94257464.py:118)
# 2024-02-06 21:32:08,873 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 16 / 30 - Success saved image: IMG_1707229928869.jpg - Testing the nozzle of a rocket engine created using 3D printing technology. (94257464.py:118)
# 2024-02-06 21:32:15,814 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 31 / 45 - Success saved image: IMG_1707229935801.jpg - Smart Lunar Investigation Landing Station (SLIM) at Tanegashima Space Center on June 1. (94257464.py:118)
# 2024-02-06 21:32:15,817 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 1 / 15 - Success saved image: IMG_1707229935810.jpg - Dog-like robot Bert receives control help from an astronaut in space (94257464.py:118)
# 2024-02-06 21:32:19,265 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 16 / 30 - Success saved image: IMG_1707229939261.jpg - Psyche spacecraft (94257464.py:118)
# 2024-02-06 21:32:28,205 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 1 / 15 - Success saved image: IMG_1707229948194.jpg - The world's most powerful rocket Starship was soon requisitioned by the Pentagon. (94257464.py:118)
# 2024-02-06 21:32:28,261 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 31 / 45 - Success saved image: IMG_1707229948255.jpg - A lone ice planet in the universe. (94257464.py:118)
# 2024-02-06 21:32:29,300 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 16 / 30 - Success saved image: IMG_1707229949294.jpg - “Message in a bottle” also carries a unique poem. (94257464.py:118)
# 2024-02-06 21:32:39,217 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 31 / 45 - Success saved image: IMG_1707229959214.jpg - Luna 25's first photo of the lunar surface. (94257464.py:118)
# 2024-02-06 21:32:40,001 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 16 / 30 - Success saved image: IMG_1707229959998.jpg - SpaceX's Falcon 9 rocket carrying 60 Starlink satellites left the launch pad (94257464.py:118)
# 2024-02-06 21:32:42,044 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 2 / 15 - Success saved image: IMG_1707229962041.jpg - A group of stars is called a globular cluster. (94257464.py:118)
# 2024-02-06 21:32:50,621 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 16 / 30 - Success saved image: IMG_1707229970612.jpg - NASA has just released a new photo of the Christmas Tree Galaxy Cluster named MACS0416. (94257464.py:118)
# 2024-02-06 21:32:52,250 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 32 / 45 - Success saved image: IMG_1707229972239.jpg - India has completed its mission to land and do scientific research at the south pole of the Moon. (94257464.py:118)
# 2024-02-06 21:32:52,282 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 2 / 15 - Success saved image: IMG_1707229972278.jpg - Inside the factory of rocket technology company LandSpace. (94257464.py:118)
# 2024-02-06 21:33:02,983 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 2 / 15 - Success saved image: IMG_1707229982973.jpg - NASA's OSIRIS-APEX spacecraft will study the asteroid Apophis (94257464.py:118)
# 2024-02-06 21:33:03,437 - thread 1 - ERROR - thread 1 - Page: 17 / 30 - Failed to save image: Image not found (94257464.py:85)
# 2024-02-06 21:33:04,605 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 32 / 45 - Success saved image: IMG_1707229984593.jpg - Aditya-L1's seven instruments are designed to observe the Sun's atmosphere (94257464.py:118)
# 2024-02-06 21:33:13,086 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 2 / 15 - Success saved image: IMG_1707229993083.jpg - Comet 12P/Pons-Brooks, also known as the "evil comet" (94257464.py:118)
# 2024-02-06 21:33:14,920 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 32 / 45 - Success saved image: IMG_1707229994916.jpg - Planet HAT-P-32b possesses a giant gas tail (94257464.py:118)
# 2024-02-06 21:33:15,858 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 17 / 30 - Success saved image: IMG_1707229995852.jpg - Surface of Mercury. (94257464.py:118)
# 2024-02-06 21:33:23,703 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 2 / 15 - Success saved image: IMG_1707230003701.jpg - The photo was taken by the SLIM ship after restoring operations. (94257464.py:118)
# 2024-02-06 21:33:25,056 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 32 / 45 - Success saved image: IMG_1707230005050.jpg - The Earth's crust consists of many tectonic plates that are constantly moving (94257464.py:118)
# 2024-02-06 21:33:26,310 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 17 / 30 - Success saved image: IMG_1707230006308.jpg - Simulation of the planet ROXs 42 Bb. (94257464.py:118)
# 2024-02-06 21:33:34,428 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 2 / 15 - Success saved image: IMG_1707230014421.jpg - A new perspective taken from inside the International Space Station (ISS) (94257464.py:118)
# 2024-02-06 21:33:35,951 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 32 / 45 - Success saved image: IMG_1707230015940.jpg - The capsule carries a simulated sample during a drop test in the Utah desert. (94257464.py:118)
# 2024-02-06 21:33:42,756 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 17 / 30 - Success saved image: IMG_1707230022747.jpg - Antimatter and positive matter will destroy each other when they come into contact. (94257464.py:118)
# 2024-02-06 21:33:45,611 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 2 / 15 - Success saved image: IMG_1707230025608.jpg - Globular cluster 47 Tucanae and the location where strange radio signals were discovered (94257464.py:118)
# 2024-02-06 21:33:47,030 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 32 / 45 - Success saved image: IMG_1707230027019.jpg - Robot Pragyan weighs only as much as a sheepdog. (94257464.py:118)
# 2024-02-06 21:33:56,300 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 2 / 15 - Success saved image: IMG_1707230036296.jpg - Astronaut models were developed by the Russian company Zvezda. (94257464.py:118)
# 2024-02-06 21:33:58,093 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 32 / 45 - Success saved image: IMG_1707230038090.jpg - Fantasy ghost NGC 6684 (94257464.py:118)
# 2024-02-06 21:34:01,202 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 17 / 30 - Success saved image: IMG_1707230041200.jpg - Asteroid Dinkinesh and its surprising companion. (94257464.py:118)
# 2024-02-06 21:34:06,783 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 2 / 15 - Success saved image: IMG_1707230046781.jpg - The shape of the universe is not what you think: From the ancient round sky to the modern three-dimensional doughnut photo 0 (94257464.py:118)
# 2024-02-06 21:34:08,041 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 32 / 45 - Success saved image: IMG_1707230048039.jpg - Simulation of Vikram lander and Pragyan robot during the Chandrayaan-3 Moon mission. (94257464.py:118)
# 2024-02-06 21:34:11,313 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 17 / 30 - Success saved image: IMG_1707230051304.jpg - The ghostly "bone hand" was just captured by IXPE (94257464.py:118)
# 2024-02-06 21:34:20,073 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 32 / 45 - Success saved image: IMG_1707230060069.jpg - The far side of the Moon (94257464.py:118)
# 2024-02-06 21:34:21,490 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 17 / 30 - Success saved image: IMG_1707230061486.jpg - The Dream Chaser plane is about to be tested in space. (94257464.py:118)
# 2024-02-06 21:34:26,886 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 2 / 15 - Success saved image: IMG_1707230066884.jpg - Planet GJ 9827d (94257464.py:118)
# 2024-02-06 21:34:33,501 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 17 / 30 - Success saved image: IMG_1707230073498.jpg - Arrow anti-ballistic missile launch system. (94257464.py:118)
# 2024-02-06 21:34:34,186 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 32 / 45 - Success saved image: IMG_1707230074184.jpg - Close-up image of the Moon's surface on August 20. (94257464.py:118)
# 2024-02-06 21:34:36,969 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 2 / 15 - Success saved image: IMG_1707230076962.jpg - Illustration of asteroid 2024 BJ flying past Earth. (94257464.py:118)
# 2024-02-06 21:34:43,564 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 17 / 30 - Success saved image: IMG_1707230083549.jpg - The moon is one of the latest "victims" due to debris from space activity (94257464.py:118)
# 2024-02-06 21:34:46,130 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 32 / 45 - Success saved image: IMG_1707230086122.jpg - Seven "promised lands" for life around the star TRAPPIST-1 (94257464.py:118)
# 2024-02-06 21:34:47,193 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 2 / 15 - Success saved image: IMG_1707230087189.jpg - The cargo ship Thien Chau-7 was launched by a Long March-7 rocket. (94257464.py:118)
# 2024-02-06 21:34:53,569 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 17 / 30 - Success saved image: IMG_1707230093565.jpg - The process of forming life on Earth may have happened on Venus (94257464.py:118)
# 2024-02-06 21:34:55,965 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 32 / 45 - Success saved image: IMG_1707230095962.jpg - OSIRIS-REx spacecraft. (94257464.py:118)
# 2024-02-06 21:34:57,251 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 2 / 15 - Success saved image: IMG_1707230097248.jpg - Supermassive black hole in spiral galaxy NGC 1365. (94257464.py:118)
# 2024-02-06 21:35:03,899 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 17 / 30 - Success saved image: IMG_1707230103889.jpg - Graphic image depicting the black hole Sagittarius A* (Sgr A*), the Milky Way and Earth (94257464.py:118)
# 2024-02-06 21:35:05,888 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 32 / 45 - Success saved image: IMG_1707230105886.jpg - The full moon coincides with the supermoon rising in New York. (94257464.py:118)
# 2024-02-06 21:35:07,609 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 2 / 15 - Success saved image: IMG_1707230107605.jpg - Graphic image depicting "object from the first second of the universe" approaching an Earth-like planet. (94257464.py:118)
# 2024-02-06 21:35:14,069 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 17 / 30 - Success saved image: IMG_1707230114058.jpg - Neptune is the planet furthest from the Sun in the solar system. (94257464.py:118)
# 2024-02-06 21:35:15,684 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 32 / 45 - Success saved image: IMG_1707230115679.jpg - Prime Minister Narendra Modi spoke after the Chandrayaan-3 spacecraft landed on the Moon (94257464.py:118)
# 2024-02-06 21:35:17,630 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 2 / 15 - Success saved image: IMG_1707230117627.jpg - Vietnam's radar satellite will launch into orbit in early 2025 photo 0 (94257464.py:118)
# 2024-02-06 21:35:27,803 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 32 / 45 - Success saved image: IMG_1707230127793.jpg - Launch of Chandrayaan-3 from Satish Dhawan space center, India (94257464.py:118)
# 2024-02-06 21:35:30,262 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 17 / 30 - Success saved image: IMG_1707230130249.jpg - The biggest question of humanity: Are we alone in the universe? photo 0 (94257464.py:118)
# 2024-02-06 21:35:32,702 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 3 / 15 - Success saved image: IMG_1707230132699.jpg - Photo of the SLIM spacecraft taken when landing (left) and when restoring operations. (94257464.py:118)
# 2024-02-06 21:35:40,298 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 17 / 30 - Success saved image: IMG_1707230140295.jpg - SQX-2Y missile. (94257464.py:118)
# 2024-02-06 21:35:40,719 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 33 / 45 - Success saved image: IMG_1707230140715.jpg - Simulating a black hole in outer space. (94257464.py:118)
# 2024-02-06 21:35:42,556 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 3 / 15 - Success saved image: IMG_1707230142553.jpg - Jupiter's life moon Europa with the Europa Clipper spacecraft (94257464.py:118)
# 2024-02-06 21:35:50,792 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 17 / 30 - Success saved image: IMG_1707230150781.jpg - Illustration of the Voyager spacecraft. (94257464.py:118)
# 2024-02-06 21:35:50,804 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 33 / 45 - Success saved image: IMG_1707230150787.jpg - Detection of "Hot Jupiter" with a temperature difference of up to 6,000 degrees on the two surfaces (94257464.py:118)
# 2024-02-06 21:35:52,555 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 3 / 15 - Success saved image: IMG_1707230152551.jpg - The Gravity-1 rocket carrying three remote sensing satellites left the launch pad (94257464.py:118)
# 2024-02-06 21:36:00,678 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 33 / 45 - Success saved image: IMG_1707230160675.jpg - Neptune's atmosphere was layered by MUSE, revealing many unusual details (94257464.py:118)
# 2024-02-06 21:36:03,077 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 3 / 15 - Success saved image: IMG_1707230163069.jpg - Asteroid 2007 FT3 is estimated to have 89 potential impacts on Earth. (94257464.py:118)
# 2024-02-06 21:36:03,928 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 18 / 30 - Success saved image: IMG_1707230163923.jpg - Nube Galaxy (94257464.py:118)
# 2024-02-06 21:36:10,558 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 33 / 45 - Success saved image: IMG_1707230170551.jpg - Jupiter's moon Europa (94257464.py:118)
# 2024-02-06 21:36:12,930 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 3 / 15 - Success saved image: IMG_1707230172927.jpg - "Unexplained entity" Barbenheimer appears from the world 13 billion years ago (94257464.py:118)
# 2024-02-06 21:36:14,100 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 18 / 30 - Success saved image: IMG_1707230174092.jpg - The US Palomar Observatory received a signal from Psyche after just 50 seconds (94257464.py:118)
# 2024-02-06 21:36:20,445 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 33 / 45 - Success saved image: IMG_1707230180442.jpg - Illustrative image of the Moon lander expected to land on the celestial surface. (94257464.py:118)
# 2024-02-06 21:36:23,171 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 3 / 15 - Success saved image: IMG_1707230183166.jpg - Model of the Lunar Lander (94257464.py:118)
# 2024-02-06 21:36:24,289 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 18 / 30 - Success saved image: IMG_1707230184287.jpg - Simulation of different planets of the Solar System. (94257464.py:118)
# 2024-02-06 21:36:30,407 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 33 / 45 - Success saved image: IMG_1707230190397.jpg - Simulation of the solar power production system in space SPS-ALPHA. (94257464.py:118)
# 2024-02-06 21:36:33,406 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 3 / 15 - Success saved image: IMG_1707230193397.jpg - The distant bright spot is a cluster of galaxies emitting strange radio waves (94257464.py:118)
# 2024-02-06 21:36:34,677 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 18 / 30 - Success saved image: IMG_1707230194673.jpg - Starship rocket at the space launch site in Boca Chica, USA (94257464.py:118)
# 2024-02-06 21:36:40,328 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 33 / 45 - Success saved image: IMG_1707230200323.jpg - The Lunar Reconnaissance Orbiter photographed a crater possibly caused by the Russian Luna-25 spacecraft (94257464.py:118)
# 2024-02-06 21:36:43,471 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 3 / 15 - Success saved image: IMG_1707230203467.jpg - Simulation of the 1783 meteor shower. (94257464.py:118)
# 2024-02-06 21:36:44,993 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 18 / 30 - Success saved image: IMG_1707230204982.jpg - In about four billion years, the Milky Way will collide with the Andromera galaxy (94257464.py:118)
# 2024-02-06 21:36:50,127 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 33 / 45 - Success saved image: IMG_1707230210125.jpg - Galactic Energy's Pallas 1 rocket. (94257464.py:118)
# 2024-02-06 21:36:55,599 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 3 / 15 - Success saved image: IMG_1707230215597.jpg - Peregrine landing ship (94257464.py:118)
# 2024-02-06 21:37:01,227 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 18 / 30 - Success saved image: IMG_1707230221225.jpg - The 9th planet has not yet been found. (94257464.py:118)
# 2024-02-06 21:37:02,099 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 33 / 45 - Success saved image: IMG_1707230222096.jpg - Solar eclipse 2012 in Texas. (94257464.py:118)
# 2024-02-06 21:37:05,489 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 3 / 15 - Success saved image: IMG_1707230225483.jpg - As the Artemis 3 program is about to launch to the Moon in 2026 (94257464.py:118)
# 2024-02-06 21:37:11,948 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 33 / 45 - Success saved image: IMG_1707230231934.jpg - The “maximum possible recoil speed” when black holes collide is 102 million km/h (94257464.py:118)
# 2024-02-06 21:37:15,430 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 3 / 15 - Success saved image: IMG_1707230235426.jpg - The Vulcan Centaur rocket carrying the Peregrine lunar lander lifts off from the launch pad. (94257464.py:118)
# 2024-02-06 21:37:17,272 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 18 / 30 - Success saved image: IMG_1707230237262.jpg - Simulation of the AT2022tsd explosion in space. (94257464.py:118)
# 2024-02-06 21:37:21,840 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 33 / 45 - Success saved image: IMG_1707230241838.jpg - Mysterious dark spot in Neptune's atmosphere photo 0 (94257464.py:118)
# 2024-02-06 21:37:27,352 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 18 / 30 - Success saved image: IMG_1707230247349.jpg - Laguna Colorada Lake, also known as Red Lagoon, in the Bolivian Andes photographed on September 7, 2023 (94257464.py:118)
# 2024-02-06 21:37:27,745 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 3 / 15 - Success saved image: IMG_1707230247735.jpg - Simorgh 2-stage booster rocket carrying 3 satellites leaves the launch pad (94257464.py:118)
# 2024-02-06 21:37:31,792 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 33 / 45 - Success saved image: IMG_1707230251788.jpg - Former Soviet astronomer Nikolai Kardashev (94257464.py:118)
# 2024-02-06 21:37:37,973 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 3 / 15 - Success saved image: IMG_1707230257970.jpg - Simulation of the Solar Space Power Demonstrator satellite in low orbit. (94257464.py:118)
# 2024-02-06 21:37:39,829 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 18 / 30 - Success saved image: IMG_1707230259823.jpg - The capsule carrying the Shenzhou 16 crew landed at Dongfeng. (94257464.py:118)
# 2024-02-06 21:37:45,763 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 33 / 45 - Success saved image: IMG_1707230265760.jpg - A superstorm outbreak on Saturn (94257464.py:118)
# 2024-02-06 21:37:48,475 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 3 / 15 - Success saved image: IMG_1707230268468.jpg - A ball of fire erupted from the Sun (94257464.py:118)
# 2024-02-06 21:37:49,719 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 18 / 30 - Success saved image: IMG_1707230269711.jpg - The graphic depicts a world of life that may be wandering at the edge of the Milky Way (94257464.py:118)
# 2024-02-06 21:37:55,670 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 33 / 45 - Success saved image: IMG_1707230275663.jpg - Image taken by Luna-25 on August 13, showing the mission symbol (center) mounted on the ship. (94257464.py:118)
# 2024-02-06 21:37:58,790 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 3 / 15 - Success saved image: IMG_1707230278781.jpg - China tested potato varieties brought back by the Shenzhou-16 ship from space photo 0 (94257464.py:118)
# 2024-02-06 21:38:00,150 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 18 / 30 - Success saved image: IMG_1707230280147.jpg - Scientists successfully grow plants on the Moon thanks to Earth bacteria photo 0 (94257464.py:118)
# 2024-02-06 21:38:05,476 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 33 / 45 - Success saved image: IMG_1707230285468.jpg - Panorama of the sky with Earendel seen through a gravitational lens (94257464.py:118)
# 2024-02-06 21:38:10,473 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 18 / 30 - Success saved image: IMG_1707230290470.jpg - A "zombie" satellite abandoned for nearly half a century suddenly sent a signal to Earth, image 0 (94257464.py:118)
# 2024-02-06 21:38:11,821 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 4 / 15 - Success saved image: IMG_1707230291818.jpg - Space junk (94257464.py:118)
# 2024-02-06 21:38:18,773 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 34 / 45 - Success saved image: IMG_1707230298770.jpg - A variant of a neutron star is called a magnetar. (94257464.py:118)
# 2024-02-06 21:38:24,240 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 4 / 15 - Success saved image: IMG_1707230304222.jpg - A mosaic of 19 JWST images of spiral galaxies. (94257464.py:118)
# 2024-02-06 21:38:28,622 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 34 / 45 - Success saved image: IMG_1707230308618.jpg - The moon Io with the Juno spacecraft in the foreground and Jupiter in the background (94257464.py:118)
# 2024-02-06 21:38:28,664 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 18 / 30 - Success saved image: IMG_1707230308659.jpg - The first image depicting a space fighter intercepting satellites has just been published (94257464.py:118)
# 2024-02-06 21:38:35,429 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 4 / 15 - Success saved image: IMG_1707230315425.jpg - This supernova shows clear periodic changes in brightness. (94257464.py:118)
# 2024-02-06 21:38:38,468 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 18 / 30 - Success saved image: IMG_1707230318463.jpg - Illustration of an asteroid crashing into Earth. (94257464.py:118)
# 2024-02-06 21:38:38,597 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 34 / 45 - Success saved image: IMG_1707230318591.jpg - Traces of high-frequency magnetic waves "wander" throughout the corona (94257464.py:118)
# 2024-02-06 21:38:45,407 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 4 / 15 - Success saved image: IMG_1707230325397.jpg - Neil Armstrong loves Playtex space suits. (94257464.py:118)
# 2024-02-06 21:38:48,309 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 18 / 30 - Success saved image: IMG_1707230328297.jpg - Einstein believed that no object in this world could reach the speed of light. (94257464.py:118)
# 2024-02-06 21:38:48,497 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 34 / 45 - Success saved image: IMG_1707230328493.jpg - Path of comet Nishimura (94257464.py:118)
# 2024-02-06 21:38:55,466 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 4 / 15 - Success saved image: IMG_1707230335464.jpg - SpaceX rocket launches on second flight. (94257464.py:118)
# 2024-02-06 21:38:58,371 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 34 / 45 - Success saved image: IMG_1707230338365.jpg - Graphic depicting ancient Maisie (94257464.py:118)
# 2024-02-06 21:39:05,848 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 4 / 15 - Success saved image: IMG_1707230345837.jpg - Yellow SLIM lander on the Moon's surface. (94257464.py:118)
# 2024-02-06 21:39:07,936 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 19 / 30 - Success saved image: IMG_1707230347933.jpg - NASA tests an 8-rotor space drone photo 0 (94257464.py:118)
# 2024-02-06 21:39:10,688 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 34 / 45 - Success saved image: IMG_1707230350685.jpg - Launch of Russia's Luna-25 lander on August 11. (94257464.py:118)
# 2024-02-06 21:39:16,345 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 4 / 15 - Success saved image: IMG_1707230356331.jpg - Star system HD 63433 with HD 63433d is the planet closest to the parent star, tidally locked (94257464.py:118)
# 2024-02-06 21:39:18,091 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 19 / 30 - Success saved image: IMG_1707230358088.jpg - NASA discovered the most distant black hole ever. (94257464.py:118)
# 2024-02-06 21:39:20,567 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 34 / 45 - Success saved image: IMG_1707230360564.jpg - "Portrait" of the "mysterious fire" ASASSN-14li (94257464.py:118)
# 2024-02-06 21:39:26,437 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 4 / 15 - Success saved image: IMG_1707230366432.jpg - SpaceX's Falcon 9 rocket carries the Dragon spacecraft carrying the Ax-3 crew (94257464.py:118)
# 2024-02-06 21:39:28,188 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 19 / 30 - Success saved image: IMG_1707230368186.jpg - Gold came to Earth thanks to space objects. (94257464.py:118)
# 2024-02-06 21:39:30,457 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 34 / 45 - Success saved image: IMG_1707230370448.jpg - India is the 4th country in the world to "set foot" on the Moon? (94257464.py:118)
# 2024-02-06 21:39:36,698 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 4 / 15 - Success saved image: IMG_1707230376693.jpg - Simulation of the shadow band that appears when the Sun narrows to a thin band of light during a solar eclipse (94257464.py:118)
# 2024-02-06 21:39:38,216 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 19 / 30 - Success saved image: IMG_1707230378213.jpg - Electrostatic tractor removes space junk inspired by science fiction photo 0 (94257464.py:118)
# 2024-02-06 21:39:42,358 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 34 / 45 - Success saved image: IMG_1707230382355.jpg - The Ring Nebula was clearly imaged with the James Webb Telescope. (94257464.py:118)
# 2024-02-06 21:39:49,334 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 4 / 15 - Success saved image: IMG_1707230389332.jpg - The asteroid crashed into eastern Germany on January 21. (94257464.py:118)
# 2024-02-06 21:39:50,176 - thread 1 - ERROR - thread 1 - Page: 19 / 30 - Failed to save image: Image not found (94257464.py:85)
# 2024-02-06 21:39:52,292 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 34 / 45 - Success saved image: IMG_1707230392287.jpg - The 7th crew sent by SpaceX to the International Space Station (ISS) consists of 4 people. (94257464.py:118)
# 2024-02-06 21:39:59,403 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 4 / 15 - Success saved image: IMG_1707230399395.jpg - The "magic islands" are found on the "planet-like moon" Titan (94257464.py:118)
# 2024-02-06 21:40:01,362 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 19 / 30 - Success saved image: IMG_1707230401352.jpg - Illustration of a satellite burning up as it reenters Earth's upper atmosphere. (94257464.py:118)
# 2024-02-06 21:40:02,266 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 34 / 45 - Success saved image: IMG_1707230402255.jpg - The Perseids meteor shower in August 2023 is an event worth looking forward to for astronomy lovers. (94257464.py:118)
# 2024-02-06 21:40:09,639 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 4 / 15 - Success saved image: IMG_1707230409637.jpg - The spacecraft successfully landed on the Moon using optical navigation. (94257464.py:118)
# 2024-02-06 21:40:11,711 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 19 / 30 - Success saved image: IMG_1707230411700.jpg - Image of Vikram lander (left) and Pragyan probe on the Moon. (94257464.py:118)
# 2024-02-06 21:40:12,259 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 34 / 45 - Success saved image: IMG_1707230412249.jpg - Russia's special goal when sending spacecraft to explore the Moon photo 0 (94257464.py:118)
# 2024-02-06 21:40:20,367 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 4 / 15 - Success saved image: IMG_1707230420360.jpg - The last 10 left-shaped objects were identified as early galaxies (94257464.py:118)
# 2024-02-06 21:40:26,478 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 34 / 45 - Success saved image: IMG_1707230426475.jpg - Extraterrestrial treasures in Michigan state are studied in the laboratory (94257464.py:118)
# 2024-02-06 21:40:28,161 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 19 / 30 - Success saved image: IMG_1707230428158.jpg - Graphic depicting an impact on the Moon, the event that created Kamo'oalewa (94257464.py:118)
# 2024-02-06 21:40:30,737 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 4 / 15 - Success saved image: IMG_1707230430734.jpg - Several tardigrade "immortal monsters" are suspected of invading the Moon (94257464.py:118)
# 2024-02-06 21:40:36,346 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 34 / 45 - Success saved image: IMG_1707230436343.jpg - Image of the Zeeman crater at the Moon's south pole. (94257464.py:118)
# 2024-02-06 21:40:38,625 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 19 / 30 - Success saved image: IMG_1707230438622.jpg - November has two small meteors. (94257464.py:118)
# 2024-02-06 21:40:40,772 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 4 / 15 - Success saved image: IMG_1707230440770.jpg - Gamma ray bursts are the strongest electromagnetic radiation phenomenon in the universe. (94257464.py:118)
# 2024-02-06 21:40:46,364 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 34 / 45 - Success saved image: IMG_1707230446362.jpg - Bold plan to turn asteroid into space station photo 0 (94257464.py:118)
# 2024-02-06 21:40:48,984 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 19 / 30 - Success saved image: IMG_1707230448981.jpg - Image of Jupiter taken by camera on the Juno probe, May 23, 2018. (94257464.py:118)
# 2024-02-06 21:40:59,207 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 19 / 30 - Success saved image: IMG_1707230459204.jpg - The Black Knight satellite has continuously transmitted radio signals for more than 50 years. (94257464.py:118)
# 2024-02-06 21:41:02,383 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 5 / 15 - Success saved image: IMG_1707230462380.jpg - Betelgeuse is so bright that it stands out in the night sky (94257464.py:118)
# 2024-02-06 21:41:03,736 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 35 / 45 - Success saved image: IMG_1707230463732.jpg - Ups and downs in Russia's Moon program photo 0 (94257464.py:118)
# 2024-02-06 21:41:17,316 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 19 / 30 - Success saved image: IMG_1707230477312.jpg - NASA's OSIRIS-APEX spacecraft is moving away from Earth (94257464.py:118)
# 2024-02-06 21:41:17,781 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 35 / 45 - Success saved image: IMG_1707230477778.jpg - Mercury (94257464.py:118)
# 2024-02-06 21:41:18,607 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 5 / 15 - Success saved image: IMG_1707230478603.jpg - The pair contains capsules in 2 sizes: 6.35mm and 12.7mm. (94257464.py:118)
# 2024-02-06 21:41:27,669 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 19 / 30 - Success saved image: IMG_1707230487665.jpg - The age of the Moon was miscalculated to more than 40 million years photo 0 (94257464.py:118)
# 2024-02-06 21:41:27,813 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 35 / 45 - Success saved image: IMG_1707230487810.jpg - Sister Keisha Schahaff and daughter Anastasia Mayers. (94257464.py:118)
# 2024-02-06 21:41:32,752 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 5 / 15 - Success saved image: IMG_1707230492749.jpg - The Aditya-L1 spacecraft launched from the Satish Dhawan Space Center in Sriharikota, India (94257464.py:118)
# 2024-02-06 21:41:37,755 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 35 / 45 - Success saved image: IMG_1707230497750.jpg - The earth entering the Lotus Dai Fire City is a seamless sphere (94257464.py:118)
# 2024-02-06 21:41:40,154 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 19 / 30 - Success saved image: IMG_1707230500151.jpg - Bacteria in Martian samples show resistance to climate change and radiation (94257464.py:118)
# 2024-02-06 21:41:42,515 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 5 / 15 - Success saved image: IMG_1707230502511.jpg - The Peregrine before launch (94257464.py:118)
# 2024-02-06 21:41:47,734 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 35 / 45 - Success saved image: IMG_1707230507721.jpg - The Chandrayaan-3 spacecraft successfully landed on the South Pole of the Moon, August 23. (94257464.py:118)
# 2024-02-06 21:41:52,541 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 19 / 30 - Success saved image: IMG_1707230512539.jpg - Anti-gravity technology: The key to lead humans to "divine" civilization! photo 0 (94257464.py:118)
# 2024-02-06 21:41:52,879 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 5 / 15 - Success saved image: IMG_1707230512871.jpg - A SpaceX Falcon Heavy sits on Launch Pad 39-A at Kennedy Space Center (94257464.py:118)
# 2024-02-06 21:41:59,907 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 35 / 45 - Success saved image: IMG_1707230519903.jpg - The Soyuz 2.1b booster rocket carrying the Luna-25 lunar probe is placed on the launch pad (94257464.py:118)
# 2024-02-06 21:42:03,583 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 5 / 15 - Success saved image: IMG_1707230523579.jpg - NGC 4945 is an active galaxy approximately 13 million light years from Earth (94257464.py:118)
# 2024-02-06 21:42:09,670 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 20 / 30 - Success saved image: IMG_1707230529667.jpg - The ISS International Space Station currently flies at a minimum orbit of up to 419.1km (94257464.py:118)
# 2024-02-06 21:42:09,913 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 35 / 45 - Success saved image: IMG_1707230529905.jpg - What is the mystery of the dark half of the Moon? (94257464.py:118)
# 2024-02-06 21:42:13,730 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 5 / 15 - Success saved image: IMG_1707230533727.jpg - The true size of the universe may far exceed our imagination. (94257464.py:118)
# 2024-02-06 21:42:20,334 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 20 / 30 - Success saved image: IMG_1707230540330.jpg - The Crab Nebula through the James Webb Telescope. (94257464.py:118)
# 2024-02-06 21:42:25,781 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 35 / 45 - Success saved image: IMG_1707230545768.jpg - Photo of part of the landing site of the Vikram lander on the Moon. (94257464.py:118)
# 2024-02-06 21:42:30,039 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 5 / 15 - Success saved image: IMG_1707230550036.jpg - A "planet with a dragon's tail" (94257464.py:118)
# 2024-02-06 21:42:30,639 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 20 / 30 - Success saved image: IMG_1707230550636.jpg - Voyager 1 travels through interstellar space. (94257464.py:118)
# 2024-02-06 21:42:37,451 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 35 / 45 - Success saved image: IMG_1707230557442.jpg - Illustration of a supermassive black hole. (94257464.py:118)
# 2024-02-06 21:42:40,020 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 5 / 15 - Success saved image: IMG_1707230560017.jpg - Space elevator design by Jordan William Hughes. (94257464.py:118)
# 2024-02-06 21:42:41,101 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 20 / 30 - Success saved image: IMG_1707230561094.jpg - Vegetables are grown on Thien Cung station (94257464.py:118)
# 2024-02-06 21:42:47,436 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 35 / 45 - Success saved image: IMG_1707230567434.jpg - The exoplanet Kappa Andromedae b has a mass 12.8 times that of Jupiter. (94257464.py:118)
# 2024-02-06 21:42:50,281 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 5 / 15 - Success saved image: IMG_1707230570275.jpg - Mercury, the planet closest to the Sun, may be full of diamonds (94257464.py:118)
# 2024-02-06 21:42:53,495 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 20 / 30 - Success saved image: IMG_1707230573482.jpg - Photos of some of the galaxies in the new map. (94257464.py:118)
# 2024-02-06 21:42:57,313 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 35 / 45 - Success saved image: IMG_1707230577310.jpg - The human body can take billions of years to completely dissolve in the vacuum of space. (94257464.py:118)
# 2024-02-06 21:43:00,091 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 5 / 15 - Success saved image: IMG_1707230580088.jpg - M-type asteroids are believed to contain many precious metals. (94257464.py:118)
# 2024-02-06 21:43:06,657 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 20 / 30 - Success saved image: IMG_1707230586645.jpg - The moon is China's ambitious destination. (94257464.py:118)
# 2024-02-06 21:43:07,316 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 35 / 45 - Success saved image: IMG_1707230587311.jpg - The bright star BD+17 2217 of the unusual galaxy Arp 263. (94257464.py:118)
# 2024-02-06 21:43:16,697 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 5 / 15 - Success saved image: IMG_1707230596694.jpg - The X-59 aircraft is expected to pave the way for silent supersonic flight over land. (94257464.py:118)
# 2024-02-06 21:43:17,372 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 35 / 45 - Success saved image: IMG_1707230597359.jpg - NASA's DART spacecraft before leaving the factory and carrying out its suicide mission (94257464.py:118)
# 2024-02-06 21:43:22,947 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 20 / 30 - Success saved image: IMG_1707230602936.jpg - The Shenzhou 17 spacecraft will take off on a Long March 2F rocket. (94257464.py:118)
# 2024-02-06 21:43:27,308 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 35 / 45 - Success saved image: IMG_1707230607305.jpg - Mysterious fireball in the sky over Melbourne city (94257464.py:118)
# 2024-02-06 21:43:28,149 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 5 / 15 - Success saved image: IMG_1707230608145.jpg - Two boys sit inside the hollow of the Willamette meteorite. (94257464.py:118)
# 2024-02-06 21:43:35,370 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 20 / 30 - Success saved image: IMG_1707230615368.jpg - Gaganyaan test launch at Satish Dhawan Space Center (94257464.py:118)
# 2024-02-06 21:43:37,343 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 35 / 45 - Success saved image: IMG_1707230617338.jpg - Simulation of the Parker probe flying past the Sun. (94257464.py:118)
# 2024-02-06 21:43:38,594 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 5 / 15 - Success saved image: IMG_1707230618589.jpg - The moon may have once contained a lot of water. (94257464.py:118)
# 2024-02-06 21:43:45,336 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 20 / 30 - Success saved image: IMG_1707230625332.jpg - Dwarf planet Ceres (94257464.py:118)
# 2024-02-06 21:43:50,127 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 36 / 45 - Success saved image: IMG_1707230630113.jpg - Shape of the constellation Perseus (94257464.py:118)
# 2024-02-06 21:43:51,210 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 5 / 15 - Success saved image: IMG_1707230631198.jpg - An astronaut poses outside the International Space Station. (94257464.py:118)
# 2024-02-06 21:43:55,741 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 20 / 30 - Success saved image: IMG_1707230635738.jpg - The concept of parallel universes offers a completely new way of explaining the universe. (94257464.py:118)
# 2024-02-06 21:44:02,293 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 36 / 45 - Success saved image: IMG_1707230642289.jpg - NASA lost contact with space station ISS photo 0 (94257464.py:118)
# 2024-02-06 21:44:04,509 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 6 / 15 - Success saved image: IMG_1707230644505.jpg - In the world we live in, countless objects are constantly moving (94257464.py:118)
# 2024-02-06 21:44:12,662 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 36 / 45 - Success saved image: IMG_1707230652657.jpg - A solar flare erupts from the surface, August 31, 2012. (94257464.py:118)
# 2024-02-06 21:44:13,677 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 20 / 30 - Success saved image: IMG_1707230653674.jpg - Super-Earths have a similar rocky structure to Earth (94257464.py:118)
# 2024-02-06 21:44:20,835 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 6 / 15 - Success saved image: IMG_1707230660832.jpg - The "cosmic hole" is a giant ring made of galaxies and galaxy clusters (94257464.py:118)
# 2024-02-06 21:44:26,655 - thread 2 - INFO - thread 2 - kh-vu-tru - Page: 36 / 45 - Success saved image: IMG_1707230666652.jpg - Four astronauts participated in the Artemis-2 mission. (94257464.py:118)
# 2024-02-06 21:44:29,847 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 20 / 30 - Success saved image: IMG_1707230669844.jpg - The Shenzhou-17 spacecraft successfully docked with the Thien Cung space station photo 0 (94257464.py:118)
# 2024-02-06 21:44:30,771 - thread 0 - INFO - thread 0 - kh-vu-tru - Page: 6 / 15 - Success saved image: IMG_1707230670769.jpg - The first photo taken by the Peregrine lander after launch. (94257464.py:118)
# ...
# 2024-02-06 22:22:32,804 - thread 0 - INFO - thread 0 - anh-dep - Page: 1 / 15 - Success saved image: IMG_1707232952792.jpg - Orion Nebula (Orion) and Trapezium Star Cluster (94257464.py:118)
# 2024-02-06 22:22:36,152 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 31 / 30 - Success saved image: IMG_1707232956149.jpg - A lone ice planet in the universe. (94257464.py:118)
# 2024-02-06 22:22:48,244 - thread 1 - INFO - thread 1 - kh-vu-tru - Page: 31 / 30 - Success saved image: IMG_1707232968241.jpg - Luna 25's first photo of the lunar surface. (94257464.py:118)
# 2024-02-06 22:23:02,725 - thread 0 - INFO - thread 0 - anh-dep - Page: 1 / 15 - Success saved image: IMG_1707232982714.jpg - Green northern lights display on Mount Sukakpak (94257464.py:118)
# 2024-02-06 22:23:04,738 - thread 1 - INFO - thread 1 - anh-dep - Page: 16 / 30 - Success saved image: IMG_1707232984726.jpg - Sword Lake in Hanoi in the period 1890-1895. (94257464.py:118)
# 2024-02-06 22:23:33,300 - thread 1 - INFO - thread 1 - anh-dep - Page: 16 / 30 - Success saved image: IMG_1707233013296.jpg - The new Mien Dong bus station is located connecting to Metro urban railway line No. 1 (94257464.py:118)
# 2024-02-06 22:23:45,996 - thread 2 - INFO - thread 2 - anh-dep - Page: 31 / 45 - Success saved image: IMG_1707233025994.jpg - Hwasong-15 missile (94257464.py:118)
# 2024-02-06 22:24:04,845 - thread 0 - INFO - thread 0 - anh-dep - Page: 1 / 15 - Success saved image: IMG_1707233044827.jpg - Old photos of the Qing Dynasty: Close-up of the "supercar" of rich aristocrats, a symbol of status and family at that time photo 0 (94257464.py:118)
# 2024-02-06 22:24:29,585 - thread 1 - INFO - thread 1 - anh-dep - Page: 16 / 30 - Success saved image: IMG_1707233069582.jpg - Bustling scene outside Ba Chieu market in 1965. (94257464.py:118)
# 2024-02-06 22:24:29,704 - thread 2 - INFO - thread 2 - anh-dep - Page: 31 / 45 - Success saved image: IMG_1707233069692.jpg - The Uzboi Vallis valley extends across Mars. (94257464.py:118)
# 2024-02-06 22:24:36,139 - thread 0 - INFO - thread 0 - anh-dep - Page: 1 / 15 - Success saved image: IMG_1707233076136.jpg - Snow covers Yongbokgung in Jongno-gu, Seoul. (94257464.py:118)
# 2024-02-06 22:24:55,348 - thread 1 - INFO - thread 1 - anh-dep - Page: 16 / 30 - Success saved image: IMG_1707233095343.jpg - Li Hongzhang was a famous mandarin at the end of the Qing Dynasty (94257464.py:118)
# 2024-02-06 22:24:58,657 - thread 2 - INFO - thread 2 - anh-dep - Page: 31 / 45 - Success saved image: IMG_1707233098652.jpg - Window frames of 2 houses at the end of the street (94257464.py:118)
# 2024-02-06 22:25:11,651 - thread 0 - INFO - thread 0 - anh-dep - Page: 1 / 15 - Success saved image: IMG_1707233111647.jpg - Seismic activity began to increase in the area around the Fagradalsfjall volcano (94257464.py:118)
# 2024-02-06 22:25:22,991 - thread 1 - INFO - thread 1 - anh-dep - Page: 16 / 30 - Success saved image: IMG_1707233122989.jpg - Photo series of historic floods submerging roads and inundating thousands of houses in Quang Binh photo 0 (94257464.py:118)
# 2024-02-06 22:25:27,186 - thread 2 - INFO - thread 2 - anh-dep - Page: 31 / 45 - Success saved image: IMG_1707233127181.jpg - The Sun is ''burping'' into the top impressive cosmic images photo 0 (94257464.py:118)
# 2024-02-06 22:25:36,774 - thread 0 - INFO - thread 0 - anh-dep - Page: 1 / 15 - Success saved image: IMG_1707233136766.jpg - King George V and Queen Mary released a simple black and white photo (94257464.py:118)
# 2024-02-06 22:25:52,573 - thread 2 - INFO - thread 2 - anh-dep - Page: 31 / 45 - Success saved image: IMG_1707233152567.jpg - Venus and Jupiter are bright in the sky of Hermosillo, Mexico. (94257464.py:118)
# 2024-02-06 22:25:55,189 - thread 1 - INFO - thread 1 - anh-dep - Page: 16 / 30 - Success saved image: IMG_1707233155178.jpg - The Bayani ship carrying Metro train No. 1 was guided by a tugboat to Saigon port (94257464.py:118)
# 2024-02-06 22:26:07,928 - thread 0 - INFO - thread 0 - anh-dep - Page: 1 / 15 - Success saved image: IMG_1707233167919.jpg - People ride horses with eagles on their shoulders during the Spring Eagle Festival in Ulaanbaatar (94257464.py:118)
# 2024-02-06 22:26:27,014 - thread 2 - INFO - thread 2 - anh-dep - Page: 31 / 45 - Success saved image: IMG_1707233186995.jpg - The super tree "chicken raspberry" is an ancient tree that is more than 150 years old. (94257464.py:118)
# 2024-02-06 22:26:42,752 - thread 1 - INFO - thread 1 - anh-dep - Page: 16 / 30 - Success saved image: IMG_1707233202749.jpg - Hanoi flagpole past and present. (94257464.py:118)
# 2024-02-06 22:26:56,065 - thread 0 - INFO - thread 0 - anh-dep - Page: 1 / 15 - Success saved image: IMG_1707233216052.jpg - Kangaroos in Cao Bang (94257464.py:118)
# 2024-02-06 22:26:59,341 - thread 2 - INFO - thread 2 - anh-dep - Page: 31 / 45 - Success saved image: IMG_1707233219336.jpg - Tianducheng urban area is considered a "miniature" Paris of the East. (94257464.py:118)
# 2024-02-06 22:27:05,859 - thread 1 - INFO - thread 1 - anh-dep - Page: 16 / 30 - Success saved image: IMG_1707233225854.jpg - Admire a series of unique body painting artworks that only "shine in the dark" (94257464.py:118)
# 2024-02-06 22:27:28,610 - thread 0 - INFO - thread 0 - anh-dep - Page: 1 / 15 - Success saved image: IMG_1707233248606.jpg - The tunneling robot will perform drilling from station S9 to station S12 with a total length of 4km. (94257464.py:118)
# 2024-02-06 22:27:32,752 - thread 2 - INFO - thread 2 - anh-dep - Page: 31 / 45 - Success saved image: IMG_1707233252741.jpg - The beach is stained with the blood of pilot whales and dolphins. (94257464.py:118)
# 2024-02-06 22:27:35,144 - thread 1 - INFO - thread 1 - anh-dep - Page: 16 / 30 - Success saved image: IMG_1707233255140.jpg - Little girls follow the custom of foot binding in a relatively well-off family (94257464.py:118)
# 2024-02-06 22:27:57,749 - thread 0 - INFO - thread 0 - anh-dep - Page: 1 / 15 - Success saved image: IMG_1707233277743.jpg - Chichen Itza Pyramid, Mexico (94257464.py:118)
# 2024-02-06 22:28:11,414 - thread 2 - INFO - thread 2 - anh-dep - Page: 31 / 45 - Success saved image: IMG_1707233291399.jpg - The TBM robot is an excavator complex with a total length of 70m and weight of 300 tons (94257464.py:118)
# 2024-02-06 22:28:20,442 - thread 1 - INFO - thread 1 - anh-dep - Page: 16 / 30 - Success saved image: IMG_1707233300421.jpg - Heavy rain and rising flood waters surround the Hue Citadel area (94257464.py:118)
# 2024-02-06 22:28:28,466 - thread 0 - INFO - thread 0 - anh-dep - Page: 1 / 15 - Success saved image: IMG_1707233308449.jpg - The water pipeline to the tower is made of more than 100 years old steel inside the Hang Dau water tower. (94257464.py:118)
# 2024-02-06 22:29:00,621 - thread 1 - INFO - thread 1 - anh-dep - Page: 16 / 30 - Success saved image: IMG_1707233340597.jpg - Messier 82 (Cigar galaxy) (94257464.py:118)
# 2024-02-06 22:29:02,647 - thread 0 - INFO - thread 0 - anh-dep - Page: 2 / 15 - Success saved image: IMG_1707233342633.jpg - Tshering Om (43 years old) is milking yaks at the family farm (94257464.py:118)
# 2024-02-06 22:29:09,616 - thread 2 - INFO - thread 2 - anh-dep - Page: 32 / 45 - Success saved image: IMG_1707233349599.jpg - Van Phuc silk weaving village (94257464.py:118)
# 2024-02-06 22:29:23,972 - thread 1 - INFO - thread 1 - anh-dep - Page: 16 / 30 - Success saved image: IMG_1707233363969.jpg - This is me when I go out and meet "the famous artist Van Gogh". (94257464.py:118)
# 2024-02-06 22:29:34,284 - thread 0 - INFO - thread 0 - anh-dep - Page: 2 / 15 - Success saved image: IMG_1707233374279.jpg - Queen Elizabeth II and Prince Philip (94257464.py:118)
# 2024-02-06 22:29:46,725 - thread 2 - INFO - thread 2 - anh-dep - Page: 32 / 45 - Success saved image: IMG_1707233386714.jpg - Photographer Matthieu Paley explores Greenland's Isortoq region (94257464.py:118)
# 2024-02-06 22:30:10,030 - thread 0 - INFO - thread 0 - anh-dep - Page: 2 / 15 - Success saved image: IMG_1707233410016.jpg - Europe saw record temperatures amid unrelenting heat (94257464.py:118)
# 2024-02-06 22:30:11,984 - thread 2 - INFO - thread 2 - anh-dep - Page: 32 / 45 - Success saved image: IMG_1707233411975.jpg - Location of North Brother Island (94257464.py:118)
# 2024-02-06 22:30:15,880 - thread 1 - INFO - thread 1 - anh-dep - Page: 16 / 30 - Success saved image: IMG_1707233415874.jpg - People are officially allowed to circulate on Pham Van Dong street with 12 lanes. (94257464.py:118)
# 2024-02-06 22:30:41,453 - thread 0 - INFO - thread 0 - anh-dep - Page: 2 / 15 - Success saved image: IMG_1707233441448.jpg - The gray owl greeted Monday morning but showed no signs of…enthusiasm. (94257464.py:118)
# 2024-02-06 22:30:52,411 - thread 1 - INFO - thread 1 - anh-dep - Page: 16 / 30 - Success saved image: IMG_1707233452397.jpg - The river flows through the Daintree rainforest in Australia. (94257464.py:118)
# 2024-02-06 22:30:56,013 - thread 2 - INFO - thread 2 - anh-dep - Page: 32 / 45 - Success saved image: IMG_1707233455998.jpg - This photo shows guests attending a wedding in Seoul in 1900. (94257464.py:118)
# 2024-02-06 22:31:29,815 - thread 0 - INFO - thread 0 - anh-dep - Page: 2 / 15 - Success saved image: IMG_1707233489802.jpg - John Thomson (94257464.py:118)
# 2024-02-06 22:31:30,956 - thread 2 - INFO - thread 2 - anh-dep - Page: 32 / 45 - Success saved image: IMG_1707233490953.jpg - Saturn is considered the most beautiful planet in the Solar System thanks to its bright glowing belt. (94257464.py:118)
# 2024-02-06 22:31:44,331 - thread 1 - INFO - thread 1 - anh-dep - Page: 16 / 30 - Success saved image: IMG_1707233504328.jpg - It's just a dog's ears tilted back (94257464.py:118)
# 2024-02-06 22:31:58,132 - thread 2 - INFO - thread 2 - anh-dep - Page: 32 / 45 - Success saved image: IMG_1707233518129.jpg - Satellite cloud photos at 12:30 showed that the storm had moved inland. Storm clouds cover the entire area. (94257464.py:118)
# 2024-02-06 22:32:01,117 - thread 0 - INFO - thread 0 - anh-dep - Page: 2 / 15 - Success saved image: IMG_1707233521104.jpg - Ngoc Thuy Park (Long Bien district, Hanoi) was started in December 2022 (94257464.py:118)
# 2024-02-06 22:32:34,670 - thread 1 - INFO - thread 1 - anh-dep - Page: 17 / 30 - Success saved image: IMG_1707233554656.jpg - The scene is peaceful but contains hidden death. (94257464.py:118)
# 2024-02-06 22:32:36,487 - thread 0 - INFO - thread 0 - anh-dep - Page: 2 / 15 - Success saved image: IMG_1707233556484.jpg - A residential area in 1920, today belongs to Quang Yen town. (94257464.py:118)
# 2024-02-06 22:33:09,909 - thread 1 - INFO - thread 1 - anh-dep - Page: 17 / 30 - Success saved image: IMG_1707233589903.jpg - The impressive Andromeda photo won first prize. (94257464.py:118)
# 2024-02-06 22:33:10,311 - thread 2 - INFO - thread 2 - anh-dep - Page: 32 / 45 - Success saved image: IMG_1707233590307.jpg - Rho Ophiuchi cloud cluster (94257464.py:118)
# 2024-02-06 22:33:10,596 - thread 0 - INFO - thread 0 - anh-dep - Page: 2 / 15 - Success saved image: IMG_1707233590593.jpg - Amelia Earhart, the first female pilot to fly solo across the Atlantic Ocean (94257464.py:118)
# 2024-02-06 22:33:40,544 - thread 2 - INFO - thread 2 - anh-dep - Page: 32 / 45 - Success saved image: IMG_1707233620537.jpg - Cassini spacecraft (94257464.py:118)
# 2024-02-06 22:33:45,945 - thread 1 - INFO - thread 1 - anh-dep - Page: 17 / 30 - Success saved image: IMG_1707233625928.jpg - In the photo is a soldier in the northwest of Hanoi taken in 1967. (94257464.py:118)
# 2024-02-06 22:33:48,513 - thread 0 - INFO - thread 0 - anh-dep - Page: 2 / 15 - Success saved image: IMG_1707233628497.jpg - In the photo, the wife of the first mandarin in Guangzhou, taken around 1861-1863. (94257464.py:118)
# 2024-02-06 22:34:09,124 - thread 2 - INFO - thread 2 - anh-dep - Page: 32 / 45 - Success saved image: IMG_1707233649116.jpg - The Bird Photographer of the Year 2017 photography award (94257464.py:118)
# 2024-02-06 22:34:17,270 - thread 0 - INFO - thread 0 - anh-dep - Page: 2 / 15 - Success saved image: IMG_1707233657262.jpg - The Danyang - Kunshan Bridge is located in Jiangsu province (China) and is 164km long (94257464.py:118)
# 2024-02-06 22:34:22,038 - thread 1 - INFO - thread 1 - anh-dep - Page: 17 / 30 - Success saved image: IMG_1707233662029.jpg - Coolie workers carry a large log, colonial Tonkin, Vietnam. (94257464.py:118)
# 2024-02-06 22:34:43,377 - thread 0 - INFO - thread 0 - anh-dep - Page: 2 / 15 - Success saved image: IMG_1707233683369.jpg - This is the breathtaking view over the Zanskar valley from Karsha Monastery. (94257464.py:118)
# 2024-02-06 22:34:53,929 - thread 2 - INFO - thread 2 - anh-dep - Page: 32 / 45 - Success saved image: IMG_1707233693917.jpg - It's so scary, just now I was still limp and limp but now I'm alive again... (94257464.py:118)
# 2024-02-06 22:34:58,688 - thread 1 - INFO - thread 1 - anh-dep - Page: 17 / 30 - Success saved image: IMG_1707233698681.jpg - Beautiful photo of Saturn and its rings (94257464.py:118)
# 2024-02-06 22:35:26,209 - thread 0 - INFO - thread 0 - anh-dep - Page: 2 / 15 - Success saved image: IMG_1707233726203.jpg - The winning work of excellence went to photographer Jack Zhi, in the category "Bird Behavior" (94257464.py:118)
# 2024-02-06 22:35:32,208 - thread 1 - INFO - thread 1 - anh-dep - Page: 17 / 30 - Success saved image: IMG_1707233732186.jpg - Colorful terraced fields in mid-September. (94257464.py:118)
# 2024-02-06 22:35:33,599 - thread 2 - INFO - thread 2 - anh-dep - Page: 32 / 45 - Success saved image: IMG_1707233733592.jpg - Satellite photo of Hurricane Irma on September 5 (94257464.py:118)
# 2024-02-06 22:36:00,783 - thread 2 - INFO - thread 2 - anh-dep - Page: 32 / 45 - Success saved image: IMG_1707233760772.jpg - People's cars pass through a flooded street in Key Largo on September 11. (94257464.py:118)
# 2024-02-06 22:36:15,465 - thread 1 - INFO - thread 1 - anh-dep - Page: 17 / 30 - Success saved image: IMG_1707233775444.jpg - The blessings of Khac Can District, King of Tan Ky (94257464.py:118)
# 2024-02-06 22:36:23,464 - thread 0 - INFO - thread 0 - anh-dep - Page: 2 / 15 - Success saved image: IMG_1707233783459.jpg - Hauntingly beautiful images of the Austfonna Ice Cap (94257464.py:118)
# 2024-02-06 22:36:39,569 - thread 2 - INFO - thread 2 - anh-dep - Page: 32 / 45 - Success saved image: IMG_1707233799561.jpg - A giant Nile crocodile has claimed the lives of hundreds of people in Burundi, Africa. (94257464.py:118)
# 2024-02-06 22:36:48,878 - thread 1 - INFO - thread 1 - anh-dep - Page: 17 / 30 - Success saved image: IMG_1707233808866.jpg - Image of the Nhon - Hanoi railway train returning from France photo 0 (94257464.py:118)
# 2024-02-06 22:37:25,175 - thread 1 - INFO - thread 1 - anh-dep - Page: 17 / 30 - Success saved image: IMG_1707233845169.jpg - Thang Long Bridge across the Red River was built in November 1974 (94257464.py:118)
# 2024-02-06 22:37:25,203 - thread 0 - INFO - thread 0 - anh-dep - Page: 2 / 15 - Success saved image: IMG_1707233845200.jpg - In Ha Dong, around 9:00 p.m. the moon gently appeared behind the dark clouds. (94257464.py:118)
# 2024-02-06 22:37:27,191 - thread 2 - INFO - thread 2 - anh-dep - Page: 32 / 45 - Success saved image: IMG_1707233847182.jpg - Wildlife Photograph of the Year - prestigious photography competition of the London Museum of Natural History. (94257464.py:118)
# 2024-02-06 22:37:52,469 - thread 0 - INFO - thread 0 - anh-dep - Page: 2 / 15 - Success saved image: IMG_1707233872462.jpg - Close-up of the extremely powerful CAT counterattack Secret Service team that just protected the US President's visit to Vietnam photo 0 (94257464.py:118)
# 2024-02-06 22:38:07,793 - thread 2 - INFO - thread 2 - anh-dep - Page: 32 / 45 - Success saved image: IMG_1707233887787.jpg - Pedersen Glacier (94257464.py:118)
# 2024-02-06 22:38:20,703 - thread 1 - INFO - thread 1 - anh-dep - Page: 17 / 30 - Success saved image: IMG_1707233900695.jpg - The Nhon-Hanoi Railway Station project is being built with a length of 12.5km, including 8.5km (94257464.py:118)
